# %% [markdown]
# <a href="https://colab.research.google.com/github/hhk54250/portfolio-management/blob/master/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install yahoo-finance

# %%
pip install pandas_market_calendars

# %%
import pandas as pd
import pandas_market_calendars as mcal
import pandas_datareader.data as web
from pandas_datareader.data import DataReader
data1 = web.get_data_yahoo('TIF','08/31/2019','08/31/2020',interval='d') #Tiffany & Co.

# %%
import numpy as np
import matplotlib.pyplot as plt
TIF = data1['Adj Close']
logTIF = np.log(TIF)-np.log(TIF.shift(1))
rTIF = TIF/TIF.shift(1)

plt.plot(logTIF)
plt.xlabel('year')
plt.ylabel('log retrun')
plt.title('LOGRETURN OF TIF')
# Out:
# Text(0.5, 1.0, 'LOGRETURN OF TIF')

# %%
plt.plot(rTIF)
plt.xlabel('year')
plt.ylabel('retrun')
plt.title('RETURN OF TIF')
# Out:
# Text(0.5, 1.0, 'RETURN OF TIF')

# %%
testlTIF=[]
for i in range(-4,0):
  testlTIF.append(logTIF[i])
logTIF4=logTIF[:-4]
testrTIF=[]
for i in range(-4,0):
  testrTIF.append(rTIF[i])
rTIF4=rTIF[:-4]

# %%
# %cd~

# !git clone https://github.com/hhk54250/portfolio-management.git 
pass
# Out:
# /root
# fatal: destination path 'portfolio-management' already exists and is not an empty directory.

# %%
# %cd portfolio-management
# %ls
# Out:
# /root/portfolio-management
# 'Libor rate.csv'   README.md

# %%
Libor = pd.read_csv("Libor rate.csv")
Lrate1 = Libor['USDONTD156N']
Lrate=[]
for i in range(1028,1289):
  Lrate.append(Lrate1[i])
Libor[1028:1289]
# Out:
#            DATE USDONTD156N
# 1028   2019/9/2           .
# 1029   2019/9/3     2.09063
# 1030   2019/9/4     2.09125
# 1031   2019/9/5     2.09763
# 1032   2019/9/6     2.09475
# ...         ...         ...
# 1284  2020/8/25     0.08138
# 1285  2020/8/26     0.08175
# 1286  2020/8/27       0.082
# 1287  2020/8/28     0.08088
# 1288  2020/8/31           .
#
# [261 rows x 2 columns]

# %%
exrate = pd.read_csv("exchange rate.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-3fad34bf549c> in <module>()
# ----> 1 exrate = pd.read_csv("exchange rate.csv")
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# ...
